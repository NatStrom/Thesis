# %%
## my data is a panel
## (robust) clustered standard errors
## fixed effects or random effects
##data clean up DALY WASH
import pandas as pd
import numpy as np
import os

##set a working directory
user = os.path.expanduser('~')
user

os.makedirs(f'{user}/Desktop/', exist_ok=True) 

path = os.chdir(f'{user}/Desktop/'+'GBD wash/')
file_list = os.listdir(path)
file_list
# Out:
# ['.DS_Store', 'IHME-GBD_2019_DATA-820325b5-1.csv']

# %%
# =============================================================================
## 1. IMPORT THE DATA
# =============================================================================
#import the csv files into one dataframe
#import the csv files into one dataframe
file= pd.concat(map(pd.read_csv, ['IHME-GBD_2019_DATA-820325b5-1.csv']))
df = file.copy()
display(df.head())
# Out:
#    measure_id                            measure_name  location_id  \
# 0           2  DALYs (Disability-Adjusted Life Years)          170
# 1           2  DALYs (Disability-Adjusted Life Years)          170
# 2           2  DALYs (Disability-Adjusted Life Years)          182
# 3           2  DALYs (Disability-Adjusted Life Years)          182
# 4           2  DALYs (Disability-Adjusted Life Years)          182
#
#   location_name  sex_id sex_name  age_id  age_name  cause_id  \
# 0         Congo       3     Both      22  All ages       956
# 1         Congo       3     Both      22  All ages       956
# 2        Malawi       3     Both      22  All ages       956
# 3        Malawi       3     Both      22  All ages       956
# 4        Malawi       3     Both      22  All ages       957
#
#                                 cause_name  rei_id  \
# 0  Respiratory infections and tuberculosis      82
# 1  Respiratory infections and tuberculosis     238
# 2  Respiratory infections and tuberculosis      82
# 3  Respiratory infections and tuberculosis     238
# 4                       Enteric infections      82
#
#                                     rei_name  metric_id metric_name  year  \
# 0  Unsafe water, sanitation, and handwashing          3        Rate  1990
# 1          No access to handwashing facility          3        Rate  1990
# 2  Unsafe water, sanitation, and handwashing          3        Rate  1990
# 3          No access to handwashing facility          3        Rate  1990
# 4  Unsafe water, sanitation, and handwashing          3        Rate  1990
#
#             val         upper         lower
# 0   1094.230977   1838.052066    505.145782
# 1   1094.230977   1838.052066    505.145782
# 2   2577.721592   4112.196439   1112.851738
# 3   2577.721592   4112.196439   1112.851738
# 4  17485.375252  22842.570838  12345.249184

# %%
list(df.location_name.unique())
# Out:
# ['Congo',
#  'Malawi',
#  'Madagascar',
#  'Equatorial Guinea',
#  'Angola',
#  'Comoros',
#  'Ethiopia',
#  'Eritrea',
#  'Botswana',
#  'Burundi',
#  'Central African Republic',
#  'Niger',
#  'Djibouti',
#  'Chad',
#  'Mauritania',
#  'Cabo Verde',
#  'Mozambique',
#  'Zambia',
#  "Côte d'Ivoire",
#  'Gabon',
#  'Eswatini',
#  'Zimbabwe',
#  'Benin',
#  'Democratic Republic of the Congo',
#  'Somalia',
#  'Lesotho',
#  'Namibia',
#  'Sao Tome and Principe',
#  'South Sudan',
#  'South Africa',
#  'Uganda',
#  'Kenya',
#  'Nigeria',
#  'Mali',
#  'Sudan',
#  'Liberia',
#  'Togo',
#  'United Republic of Tanzania',
#  'Gambia',
#  'Rwanda',
#  'Guinea',
#  'Ghana',
#  'Cameroon',
#  'Burkina Faso',
#  'Senegal',
#  'Sierra Leone',
#  'Guinea-Bissau']

# %%
# =============================================================================
## 2. GET DESCRIPTIVES OF DATASET
# =============================================================================
print(df.dtypes)
print(df.columns)
print(df.describe(include='all'))

## sanity check to ensure the spread of the data is correct
print('sanity check 1, ensure appropriate years and countries are represented')
list_country=list(list(df['location_name'].drop_duplicates()))
print('country list', list_country)
#inspect for NAs
print('following checks for completeness of all columns')
print('is country_id null', df['location_id'].isnull().values.any())
print('is risk_id null', df['rei_id'].isnull().values.any())
print('is risk_name null', df['rei_name'].isnull().values.any())
print('is year null', df['year'].isnull().values.any())
print('is sex null', df['sex_id'].isnull().values.any())
print('is age_group null', df['age_id'].isnull().values.any())
print('is daly_mean null', df['val'].isnull().values.any())
print('these age groups have been pulled', df['age_name'].unique())
print('these sex groups have been pulled', df['sex_name'].unique())
print('these years have been pulled', df['year'].unique())
print('these risks have been pulled', df['rei_name'].unique())

# =============================================================================
# ## 3. FILTER, RENAME AND CLEAN
# =============================================================================
#filter only the wanted columns
df = df.loc[df['metric_id'].isin([3])]
df_filtered = df.filter(['measure_name', 'location_name','location_id',
                         'sex_name', 'age_name', 'rei_id', 'cause_name',
                         'cause_id','rei_name', 'year', 'val', 'upper',
                         'lower'])
#change dtypes if neccessary
df_filtered['val'] = df_filtered['val'].astype(int)
df_filtered['upper'] = df_filtered['upper'].astype(int)
df_filtered['lower'] = df_filtered['lower'].astype(int)

#rename columns
df_filtered = df_filtered.rename(columns={'location_name': 'country',
                                          'sex_name': 'sex',
                                          'age_name':'age',
                                          'val': 'daly_mean',
                                          'upper': 'daly_upper',
                                          'lower': 'daly_lower'})
# Out:
# measure_id         int64
# measure_name      object
# location_id        int64
# location_name     object
# sex_id             int64
# sex_name          object
# age_id             int64
# age_name          object
# cause_id           int64
# cause_name        object
# rei_id             int64
# rei_name          object
# metric_id          int64
# metric_name       object
# year               int64
# val              float64
# upper            float64
# lower            float64
# dtype: object
# Index(['measure_id', 'measure_name', 'location_id', 'location_name', 'sex_id',
#        'sex_name', 'age_id', 'age_name', 'cause_id', 'cause_name', 'rei_id',
#        'rei_name', 'metric_id', 'metric_name', 'year', 'val', 'upper',
#        'lower'],
#       dtype='object')
#         measure_id                            measure_name   location_id  \
# count      28200.0                                   28200  28200.000000
# unique         NaN                                       1           NaN
# top            NaN  DALYs (Disability-Adjusted Life Years)           NaN
# freq           NaN                                   28200           NaN
# mean           2.0                                     NaN    205.914894
# std            0.0                                     NaN     60.044251
# min            2.0                                     NaN    168.000000
# 25%            2.0                                     NaN    180.000000
# 50%            2.0                                     NaN    196.000000
# 75%            2.0                                     NaN    209.000000
# max            2.0                                     NaN    522.000000
#
#        location_name   sex_id sex_name   age_id  age_name      cause_id  \
# count          28200  28200.0    28200  28200.0     28200  28200.000000
# unique            47      NaN        1      NaN         1           NaN
# top            Congo      NaN     Both      NaN  All ages           NaN
# freq             600      NaN    28200      NaN     28200           NaN
# mean             NaN      3.0      NaN     22.0       NaN    497.400000
# std              NaN      0.0      NaN      0.0       NaN    300.767764
# min              NaN      3.0      NaN     22.0       NaN    294.000000
# 25%              NaN      3.0      NaN     22.0       NaN    295.000000
# 50%              NaN      3.0      NaN     22.0       NaN    302.000000
# 75%              NaN      3.0      NaN     22.0       NaN    956.000000
# max              NaN      3.0      NaN     22.0       NaN    957.000000
#
#                 cause_name        rei_id  \
# count                28200  28200.000000
# unique                   6           NaN
# top     Enteric infections           NaN
# freq                  5640           NaN
# mean                   NaN    129.400000
# std                    NaN     71.100065
# min                    NaN     82.000000
# 25%                    NaN     82.000000
# 50%                    NaN     83.500000
# 75%                    NaN    238.000000
# max                    NaN    238.000000
#
#                                          rei_name  metric_id metric_name  \
# count                                       28200    28200.0       28200
# unique                                          4        NaN           1
# top     Unsafe water, sanitation, and handwashing        NaN        Rate
# freq                                         8460        NaN       28200
# mean                                          NaN        3.0         NaN
# std                                           NaN        0.0         NaN
# min                                           NaN        3.0         NaN
# 25%                                           NaN        3.0         NaN
# 50%                                           NaN        3.0         NaN
# 75%                                           NaN        3.0         NaN
# max                                           NaN        3.0         NaN
#
#                 year           val         upper         lower
# count   28200.000000  28200.000000  28200.000000  28200.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean     2004.500000   4973.986725   7351.941865   2998.179371
# std         8.655595   4736.861995   6896.219809   3032.977168
# min      1990.000000    118.647214    167.354675     73.926353
# 25%      1997.000000   1645.585261   2518.850637    884.555798
# 50%      2004.500000   3361.028776   5072.164810   1998.835886
# 75%      2012.000000   6814.504206  10064.430751   4108.631588
# max      2019.000000  41381.895621  57058.216476  27493.276790
# sanity check 1, ensure appropriate years and countries are represented
# country list ['Congo', 'Malawi', 'Madagascar', 'Equatorial Guinea', 'Angola', 'Comoros', 'Ethiopia', 'Eritrea', 'Botswana', 'Burundi', 'Central African Republic', 'Niger', 'Djibouti', 'Chad', 'Mauritania', 'Cabo Verde', 'Mozambique', 'Zambia', "Côte d'Ivoire", 'Gabon', 'Eswatini', 'Zimbabwe', 'Benin', 'Democratic Republic of the Congo', 'Somalia', 'Lesotho', 'Namibia', 'Sao Tome and Principe', 'South Sudan', 'South Africa', 'Uganda', 'Kenya', 'Nigeria', 'Mali', 'Sudan', 'Liberia', 'Togo', 'United Republic of Tanzania', 'Gambia', 'Rwanda', 'Guinea', 'Ghana', 'Cameroon', 'Burkina Faso', 'Senegal', 'Sierra Leone', 'Guinea-Bissau']
# following checks for completeness of all columns
# is country_id null False
# is risk_id null False
# is risk_name null False
# is year null False
# is sex null False
# is age_group null False
# is daly_mean null False
# these age groups have been pulled ['All ages']
# these sex groups have been pulled ['Both']
# these years have been pulled [1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019]
# these risks have been pulled ['Unsafe water, sanitation, and handwashing'
#  'No access to handwashing facility' 'Unsafe water source'
#  'Unsafe sanitation']

# %%
df_filtered.location_id.unique()
# Out:
# array([170, 182, 181, 172, 168, 176, 179, 178, 193, 175, 169, 213, 177,
#        204, 212, 203, 184, 191, 205, 173, 197, 198, 200, 171, 187, 194,
#        195, 215, 435, 196, 190, 180, 214, 211, 522, 210, 218, 189, 206,
#        185, 208, 207, 202, 201, 216, 217, 209])

# %%
#fix gender naming
#fix naming of the gender values
df_filtered = df_filtered.replace({'Both': 'btsx','Male':'mle','Female':'fmle'})

# %%
#only filter our level 3 WASH risk factors
df_WASH =df_filtered.copy()

# %%
df_WASH
# Out:
#                                  measure_name                country  \
# 0      DALYs (Disability-Adjusted Life Years)                  Congo
# 1      DALYs (Disability-Adjusted Life Years)                  Congo
# 2      DALYs (Disability-Adjusted Life Years)                 Malawi
# 3      DALYs (Disability-Adjusted Life Years)                 Malawi
# 4      DALYs (Disability-Adjusted Life Years)                 Malawi
# ...                                       ...                    ...
# 28195  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28196  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28197  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28198  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28199  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
#
#        location_id   sex       age  rei_id  \
# 0              170  btsx  All ages      82
# 1              170  btsx  All ages     238
# 2              182  btsx  All ages      82
# 3              182  btsx  All ages     238
# 4              182  btsx  All ages      82
# ...            ...   ...       ...     ...
# 28195          215  btsx  All ages      83
# 28196          215  btsx  All ages      84
# 28197          215  btsx  All ages     238
# 28198          215  btsx  All ages      82
# 28199          215  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 0                Respiratory infections and tuberculosis       956
# 1                Respiratory infections and tuberculosis       956
# 2                Respiratory infections and tuberculosis       956
# 3                Respiratory infections and tuberculosis       956
# 4                                     Enteric infections       957
# ...                                                  ...       ...
# 28195  Communicable, maternal, neonatal, and nutritio...       295
# 28196  Communicable, maternal, neonatal, and nutritio...       295
# 28197  Communicable, maternal, neonatal, and nutritio...       295
# 28198                       Lower respiratory infections       322
# 28199                       Lower respiratory infections       322
#
#                                         rei_name  year  daly_mean  daly_upper  \
# 0      Unsafe water, sanitation, and handwashing  1990       1094        1838
# 1              No access to handwashing facility  1990       1094        1838
# 2      Unsafe water, sanitation, and handwashing  1990       2577        4112
# 3              No access to handwashing facility  1990       2577        4112
# 4      Unsafe water, sanitation, and handwashing  1990      17485       22842
# ...                                          ...   ...        ...         ...
# 28195                        Unsafe water source  2019        356         509
# 28196                          Unsafe sanitation  2019        203         280
# 28197          No access to handwashing facility  2019        438         645
# 28198  Unsafe water, sanitation, and handwashing  2019        319         511
# 28199          No access to handwashing facility  2019        319         511
#
#        daly_lower
# 0             505
# 1             505
# 2            1112
# 3            1112
# 4           12345
# ...           ...
# 28195         224
# 28196         140
# 28197         256
# 28198         139
# 28199         139
#
# [28200 rows x 13 columns]

# %%
print(df_WASH.rei_id.unique())
print(df_WASH.rei_name.unique())
df_WASH = df_WASH.loc[df_WASH['rei_id'].isin([238,83,84])]
print(df_WASH)
# Out:
# [ 82 238  83  84]
# ['Unsafe water, sanitation, and handwashing'
#  'No access to handwashing facility' 'Unsafe water source'
#  'Unsafe sanitation']
#                                  measure_name                country  \
# 1      DALYs (Disability-Adjusted Life Years)                  Congo
# 3      DALYs (Disability-Adjusted Life Years)                 Malawi
# 5      DALYs (Disability-Adjusted Life Years)                 Malawi
# 6      DALYs (Disability-Adjusted Life Years)                 Malawi
# 7      DALYs (Disability-Adjusted Life Years)                 Malawi
# ...                                       ...                    ...
# 28193  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28195  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28196  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28197  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28199  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
#
#        location_id   sex       age  rei_id  \
# 1              170  btsx  All ages     238
# 3              182  btsx  All ages     238
# 5              182  btsx  All ages      83
# 6              182  btsx  All ages      84
# 7              182  btsx  All ages     238
# ...            ...   ...       ...     ...
# 28193          215  btsx  All ages     238
# 28195          215  btsx  All ages      83
# 28196          215  btsx  All ages      84
# 28197          215  btsx  All ages     238
# 28199          215  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 1                Respiratory infections and tuberculosis       956
# 3                Respiratory infections and tuberculosis       956
# 5                                     Enteric infections       957
# 6                                     Enteric infections       957
# 7                                     Enteric infections       957
# ...                                                  ...       ...
# 28193                                         All causes       294
# 28195  Communicable, maternal, neonatal, and nutritio...       295
# 28196  Communicable, maternal, neonatal, and nutritio...       295
# 28197  Communicable, maternal, neonatal, and nutritio...       295
# 28199                       Lower respiratory infections       322
#
#                                 rei_name  year  daly_mean  daly_upper  \
# 1      No access to handwashing facility  1990       1094        1838
# 3      No access to handwashing facility  1990       2577        4112
# 5                    Unsafe water source  1990      15669       20898
# 6                      Unsafe sanitation  1990      11806       15408
# 7      No access to handwashing facility  1990       5867        8069
# ...                                  ...   ...        ...         ...
# 28193  No access to handwashing facility  2019        438         645
# 28195                Unsafe water source  2019        356         509
# 28196                  Unsafe sanitation  2019        203         280
# 28197  No access to handwashing facility  2019        438         645
# 28199  No access to handwashing facility  2019        319         511
#
#        daly_lower
# 1             505
# 3            1112
# 5           10629
# 6            8333
# 7            3898
# ...           ...
# 28193         256
# 28195         224
# 28196         140
# 28197         256
# 28199         139
#
# [19740 rows x 13 columns]

# %%
#get iso3 codes for countries
##mport the function 
import pycountry
def findCountryAlpha3 (country_name):
    """Producing current iso alpha 3 codes from standardized country names"""
    try:
        return pycountry.countries.get(name=country_name).alpha_3
    except:
        return ('')

# %%
##create iso
df_WASH['iso'] = df_WASH.apply(lambda row: findCountryAlpha3(row.country), axis=1)
# Out:
# /var/folders/3l/pgxm2f9j3bbgbjcj2pyxl__00000gp/T/ipykernel_2958/2553773447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_WASH['iso'] = df_WASH.apply(lambda row: findCountryAlpha3(row.country), axis=1)

# %%
df_WASH
# Out:
#                                  measure_name                country  \
# 1      DALYs (Disability-Adjusted Life Years)                  Congo
# 3      DALYs (Disability-Adjusted Life Years)                 Malawi
# 5      DALYs (Disability-Adjusted Life Years)                 Malawi
# 6      DALYs (Disability-Adjusted Life Years)                 Malawi
# 7      DALYs (Disability-Adjusted Life Years)                 Malawi
# ...                                       ...                    ...
# 28193  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28195  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28196  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28197  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28199  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
#
#        location_id   sex       age  rei_id  \
# 1              170  btsx  All ages     238
# 3              182  btsx  All ages     238
# 5              182  btsx  All ages      83
# 6              182  btsx  All ages      84
# 7              182  btsx  All ages     238
# ...            ...   ...       ...     ...
# 28193          215  btsx  All ages     238
# 28195          215  btsx  All ages      83
# 28196          215  btsx  All ages      84
# 28197          215  btsx  All ages     238
# 28199          215  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 1                Respiratory infections and tuberculosis       956
# 3                Respiratory infections and tuberculosis       956
# 5                                     Enteric infections       957
# 6                                     Enteric infections       957
# 7                                     Enteric infections       957
# ...                                                  ...       ...
# 28193                                         All causes       294
# 28195  Communicable, maternal, neonatal, and nutritio...       295
# 28196  Communicable, maternal, neonatal, and nutritio...       295
# 28197  Communicable, maternal, neonatal, and nutritio...       295
# 28199                       Lower respiratory infections       322
#
#                                 rei_name  year  daly_mean  daly_upper  \
# 1      No access to handwashing facility  1990       1094        1838
# 3      No access to handwashing facility  1990       2577        4112
# 5                    Unsafe water source  1990      15669       20898
# 6                      Unsafe sanitation  1990      11806       15408
# 7      No access to handwashing facility  1990       5867        8069
# ...                                  ...   ...        ...         ...
# 28193  No access to handwashing facility  2019        438         645
# 28195                Unsafe water source  2019        356         509
# 28196                  Unsafe sanitation  2019        203         280
# 28197  No access to handwashing facility  2019        438         645
# 28199  No access to handwashing facility  2019        319         511
#
#        daly_lower  iso
# 1             505  COG
# 3            1112  MWI
# 5           10629  MWI
# 6            8333  MWI
# 7            3898  MWI
# ...           ...  ...
# 28193         256  STP
# 28195         224  STP
# 28196         140  STP
# 28197         256  STP
# 28199         139  STP
#
# [19740 rows x 14 columns]

# %%
##check the uniqueness and coverage of the iso codes
inspect = df_WASH[df_WASH['iso'].isna()]
print(inspect['iso'].unique())
# Out:
# []

# %%
list_iso = list(df_WASH.iso)
list_iso = list( dict.fromkeys(list_iso) )
print(list_iso)
# Out:
# ['COG', 'MWI', 'MDG', 'GNQ', 'AGO', 'COM', 'ETH', 'ERI', 'BWA', 'BDI', 'CAF', 'NER', 'DJI', 'TCD', 'MRT', 'CPV', 'MOZ', 'ZMB', 'CIV', 'GAB', 'SWZ', 'ZWE', 'BEN', '', 'SOM', 'LSO', 'NAM', 'STP', 'SSD', 'ZAF', 'UGA', 'KEN', 'NGA', 'MLI', 'SDN', 'LBR', 'TGO', 'GMB', 'RWA', 'GIN', 'GHA', 'CMR', 'BFA', 'SEN', 'SLE', 'GNB']

# %%
df_WASH
# Out:
#                                  measure_name                country  \
# 1      DALYs (Disability-Adjusted Life Years)                  Congo
# 3      DALYs (Disability-Adjusted Life Years)                 Malawi
# 5      DALYs (Disability-Adjusted Life Years)                 Malawi
# 6      DALYs (Disability-Adjusted Life Years)                 Malawi
# 7      DALYs (Disability-Adjusted Life Years)                 Malawi
# ...                                       ...                    ...
# 28193  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28195  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28196  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28197  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28199  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
#
#        location_id   sex       age  rei_id  \
# 1              170  btsx  All ages     238
# 3              182  btsx  All ages     238
# 5              182  btsx  All ages      83
# 6              182  btsx  All ages      84
# 7              182  btsx  All ages     238
# ...            ...   ...       ...     ...
# 28193          215  btsx  All ages     238
# 28195          215  btsx  All ages      83
# 28196          215  btsx  All ages      84
# 28197          215  btsx  All ages     238
# 28199          215  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 1                Respiratory infections and tuberculosis       956
# 3                Respiratory infections and tuberculosis       956
# 5                                     Enteric infections       957
# 6                                     Enteric infections       957
# 7                                     Enteric infections       957
# ...                                                  ...       ...
# 28193                                         All causes       294
# 28195  Communicable, maternal, neonatal, and nutritio...       295
# 28196  Communicable, maternal, neonatal, and nutritio...       295
# 28197  Communicable, maternal, neonatal, and nutritio...       295
# 28199                       Lower respiratory infections       322
#
#                                 rei_name  year  daly_mean  daly_upper  \
# 1      No access to handwashing facility  1990       1094        1838
# 3      No access to handwashing facility  1990       2577        4112
# 5                    Unsafe water source  1990      15669       20898
# 6                      Unsafe sanitation  1990      11806       15408
# 7      No access to handwashing facility  1990       5867        8069
# ...                                  ...   ...        ...         ...
# 28193  No access to handwashing facility  2019        438         645
# 28195                Unsafe water source  2019        356         509
# 28196                  Unsafe sanitation  2019        203         280
# 28197  No access to handwashing facility  2019        438         645
# 28199  No access to handwashing facility  2019        319         511
#
#        daly_lower  iso
# 1             505  COG
# 3            1112  MWI
# 5           10629  MWI
# 6            8333  MWI
# 7            3898  MWI
# ...           ...  ...
# 28193         256  STP
# 28195         224  STP
# 28196         140  STP
# 28197         256  STP
# 28199         139  STP
#
# [19740 rows x 14 columns]

# %%
##set iso manually for countries that were missed
df_WASH.loc[df_WASH['country'] == 'United Republic of Tanzania', 'iso'] = 'TZA'
df_WASH.loc[df_WASH['country'] == 'Democratic Republic of the Congo', 'iso'] = 'COD'

# %%
df_WASH
# Out:
#                                  measure_name                country  \
# 1      DALYs (Disability-Adjusted Life Years)                  Congo
# 3      DALYs (Disability-Adjusted Life Years)                 Malawi
# 5      DALYs (Disability-Adjusted Life Years)                 Malawi
# 6      DALYs (Disability-Adjusted Life Years)                 Malawi
# 7      DALYs (Disability-Adjusted Life Years)                 Malawi
# ...                                       ...                    ...
# 28193  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28195  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28196  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28197  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
# 28199  DALYs (Disability-Adjusted Life Years)  Sao Tome and Principe
#
#        location_id   sex       age  rei_id  \
# 1              170  btsx  All ages     238
# 3              182  btsx  All ages     238
# 5              182  btsx  All ages      83
# 6              182  btsx  All ages      84
# 7              182  btsx  All ages     238
# ...            ...   ...       ...     ...
# 28193          215  btsx  All ages     238
# 28195          215  btsx  All ages      83
# 28196          215  btsx  All ages      84
# 28197          215  btsx  All ages     238
# 28199          215  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 1                Respiratory infections and tuberculosis       956
# 3                Respiratory infections and tuberculosis       956
# 5                                     Enteric infections       957
# 6                                     Enteric infections       957
# 7                                     Enteric infections       957
# ...                                                  ...       ...
# 28193                                         All causes       294
# 28195  Communicable, maternal, neonatal, and nutritio...       295
# 28196  Communicable, maternal, neonatal, and nutritio...       295
# 28197  Communicable, maternal, neonatal, and nutritio...       295
# 28199                       Lower respiratory infections       322
#
#                                 rei_name  year  daly_mean  daly_upper  \
# 1      No access to handwashing facility  1990       1094        1838
# 3      No access to handwashing facility  1990       2577        4112
# 5                    Unsafe water source  1990      15669       20898
# 6                      Unsafe sanitation  1990      11806       15408
# 7      No access to handwashing facility  1990       5867        8069
# ...                                  ...   ...        ...         ...
# 28193  No access to handwashing facility  2019        438         645
# 28195                Unsafe water source  2019        356         509
# 28196                  Unsafe sanitation  2019        203         280
# 28197  No access to handwashing facility  2019        438         645
# 28199  No access to handwashing facility  2019        319         511
#
#        daly_lower  iso
# 1             505  COG
# 3            1112  MWI
# 5           10629  MWI
# 6            8333  MWI
# 7            3898  MWI
# ...           ...  ...
# 28193         256  STP
# 28195         224  STP
# 28196         140  STP
# 28197         256  STP
# 28199         139  STP
#
# [19740 rows x 14 columns]

# %%
df_WASH.query('location_id == 171')
# Out:
#                                  measure_name  \
# 144    DALYs (Disability-Adjusted Life Years)
# 145    DALYs (Disability-Adjusted Life Years)
# 146    DALYs (Disability-Adjusted Life Years)
# 192    DALYs (Disability-Adjusted Life Years)
# 279    DALYs (Disability-Adjusted Life Years)
# ...                                       ...
# 27946  DALYs (Disability-Adjusted Life Years)
# 27947  DALYs (Disability-Adjusted Life Years)
# 27948  DALYs (Disability-Adjusted Life Years)
# 28061  DALYs (Disability-Adjusted Life Years)
# 28129  DALYs (Disability-Adjusted Life Years)
#
#                                 country  location_id   sex       age  rei_id  \
# 144    Democratic Republic of the Congo          171  btsx  All ages      83
# 145    Democratic Republic of the Congo          171  btsx  All ages      84
# 146    Democratic Republic of the Congo          171  btsx  All ages     238
# 192    Democratic Republic of the Congo          171  btsx  All ages     238
# 279    Democratic Republic of the Congo          171  btsx  All ages     238
# ...                                 ...          ...   ...       ...     ...
# 27946  Democratic Republic of the Congo          171  btsx  All ages      83
# 27947  Democratic Republic of the Congo          171  btsx  All ages      84
# 27948  Democratic Republic of the Congo          171  btsx  All ages     238
# 28061  Democratic Republic of the Congo          171  btsx  All ages     238
# 28129  Democratic Republic of the Congo          171  btsx  All ages     238
#
#                                     cause_name  cause_id  \
# 144                         Diarrheal diseases       302
# 145                         Diarrheal diseases       302
# 146                         Diarrheal diseases       302
# 192               Lower respiratory infections       322
# 279    Respiratory infections and tuberculosis       956
# ...                                        ...       ...
# 27946                       Diarrheal diseases       302
# 27947                       Diarrheal diseases       302
# 27948                       Diarrheal diseases       302
# 28061             Lower respiratory infections       322
# 28129  Respiratory infections and tuberculosis       956
#
#                                 rei_name  year  daly_mean  daly_upper  \
# 144                  Unsafe water source  1990       6136        8764
# 145                    Unsafe sanitation  1990       4565        6368
# 146    No access to handwashing facility  1990       2358        3345
# 192    No access to handwashing facility  1990       2503        3979
# 279    No access to handwashing facility  1991       2449        3873
# ...                                  ...   ...        ...         ...
# 27946                Unsafe water source  2019       2326        4305
# 27947                  Unsafe sanitation  2019       1648        3039
# 27948  No access to handwashing facility  2019        899        1687
# 28061  No access to handwashing facility  2019        570         943
# 28129  No access to handwashing facility  2019        570         943
#
#        daly_lower  iso
# 144          4128  COD
# 145          3209  COD
# 146          1591  COD
# 192          1176  COD
# 279          1165  COD
# ...           ...  ...
# 27946        1021  COD
# 27947         739  COD
# 27948         389  COD
# 28061         259  COD
# 28129         259  COD
#
# [420 rows x 14 columns]

# %%
list(df_WASH.iso.unique())
df_WASH.head()
df_WASH.columns
# Out:
# Index(['measure_name', 'country', 'location_id', 'sex', 'age', 'rei_id',
#        'cause_name', 'cause_id', 'rei_name', 'year', 'daly_mean', 'daly_upper',
#        'daly_lower', 'iso'],
#       dtype='object')

# %%
df_WASH.iso.unique()
# Out:
# array(['COG', 'MWI', 'MDG', 'GNQ', 'AGO', 'COM', 'ETH', 'ERI', 'BWA',
#        'BDI', 'CAF', 'NER', 'DJI', 'TCD', 'MRT', 'CPV', 'MOZ', 'ZMB',
#        'CIV', 'GAB', 'SWZ', 'ZWE', 'BEN', 'COD', 'SOM', 'LSO', 'NAM',
#        'STP', 'SSD', 'ZAF', 'UGA', 'KEN', 'NGA', 'MLI', 'SDN', 'LBR',
#        'TGO', 'TZA', 'GMB', 'RWA', 'GIN', 'GHA', 'CMR', 'BFA', 'SEN',
#        'SLE', 'GNB'], dtype=object)

# %%
#safe data to csv as back up
os.getcwd()
df_WASH.to_csv('df_DALY_SSA.csv')
