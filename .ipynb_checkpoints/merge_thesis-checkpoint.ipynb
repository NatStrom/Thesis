# %% [markdown]
# ## Merge

# %%
import pandas as pd
import numpy as np
import os

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import both dfs
##set a working directory
user = os.path.expanduser('~')
display(user)

os.makedirs(f'{user}/Desktop/thesis/', exist_ok=True)
path = os.chdir(f'{user}/Desktop/'+'thesis/')

data_conflict = pd.read_csv('df_conflict.csv')
data_DALY = pd.read_csv('df_East_standard.csv')
# Out:
# '/Users/NatStrom'

# %%
data_conflict.dtypes
# Out:
# Unnamed: 0      int64
# c_id            int64
# year            int64
# best_ns       float64
# best_os       float64
# best_sb       float64
# best_all      float64
# dtype: object

# %%
data_DALY.dtypes
# Out:
# Unnamed: 0       int64
# measure_name    object
# country         object
# sex             object
# age             object
# rei_id           int64
# cause_name      object
# cause_id         int64
# rei_name        object
# year             int64
# daly_mean        int64
# daly_upper       int64
# daly_lower       int64
# region_SSA      object
# iso             object
# dtype: object

# %%
data_DALY = data_DALY.rename(columns= {'year':'year_id'})
data_conflict = data_conflict.rename(columns= {'year':'year_id'})

# %%
from ingester3.scratch import cache_manager

cache_manager()

# This will import the Pandas extensions as well as bootstrap the object layer
from ingester3.extensions import *

# %%
data_DALY = pd.DataFrame.cy.soft_validate_iso_year(data_DALY, iso_col='iso', year_col = 'year_id', at_month = 12)
inspect = data_DALY.query("valid_id == False")
print('countries with invalid id below')
display(inspect)

data_DALY = pd.DataFrame.cy.from_iso_year(data_DALY[data_DALY['valid_id']==True], iso_col = 'iso', year_col = 'year_id', at_month = 12)
data_DALY = data_DALY.c.db_id()
#inspect = data_DALY.loc[data_DALY.cy_id.isna()]
print('countries with cy_id na below')
display(inspect)
# Out:
# countries with invalid id below
#        Unnamed: 0                            measure_name  \
# 38          15073  DALYs (Disability-Adjusted Life Years)
# 39          15074  DALYs (Disability-Adjusted Life Years)
# 40          15081  DALYs (Disability-Adjusted Life Years)
# 41          15115  DALYs (Disability-Adjusted Life Years)
# 42          15116  DALYs (Disability-Adjusted Life Years)
# ...           ...                                     ...
# 11705      457074  DALYs (Disability-Adjusted Life Years)
# 11706      457075  DALYs (Disability-Adjusted Life Years)
# 11707      457078  DALYs (Disability-Adjusted Life Years)
# 11708      457862  DALYs (Disability-Adjusted Life Years)
# 11709      457886  DALYs (Disability-Adjusted Life Years)
#
#                            country   sex       age  rei_id  \
# 38                     South Sudan  btsx  All ages      83
# 39                     South Sudan  btsx  All ages      84
# 40                     South Sudan  btsx  All ages     238
# 41                     South Sudan  btsx  All ages      83
# 42                     South Sudan  btsx  All ages      84
# ...                            ...   ...       ...     ...
# 11705  United Republic of Tanzania  btsx  All ages      83
# 11706  United Republic of Tanzania  btsx  All ages      84
# 11707  United Republic of Tanzania  btsx  All ages     238
# 11708  United Republic of Tanzania  btsx  All ages     238
# 11709  United Republic of Tanzania  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 38                                            All causes       294
# 39                                            All causes       294
# 40                                            All causes       294
# 41                                            All causes       294
# 42                                            All causes       294
# ...                                                  ...       ...
# 11705  Communicable, maternal, neonatal, and nutritio...       295
# 11706  Communicable, maternal, neonatal, and nutritio...       295
# 11707  Communicable, maternal, neonatal, and nutritio...       295
# 11708                       Lower respiratory infections       322
# 11709                       Lower respiratory infections       322
#
#                                 rei_name  year_id  daly_mean  daly_upper  \
# 38                   Unsafe water source     1990     387194      679639
# 39                     Unsafe sanitation     1990     292342      518583
# 40     No access to handwashing facility     1990     339585      503025
# 41                   Unsafe water source     1990       6608       11598
# 42                     Unsafe sanitation     1990       4989        8850
# ...                                  ...      ...        ...         ...
# 11705                Unsafe water source     2007       2593        3429
# 11706                  Unsafe sanitation     2007       1920        2506
# 11707  No access to handwashing facility     2007       2455        3334
# 11708  No access to handwashing facility     2007     600721      919424
# 11709  No access to handwashing facility     2007       1454        2225
#
#        daly_lower region_SSA  iso  valid_id
# 38         234344   SSA_east  SSD     False
# 39         182239   SSA_east  SSD     False
# 40         211039   SSA_east  SSD     False
# 41           3999   SSA_east  SSD     False
# 42           3110   SSA_east  SSD     False
# ...           ...        ...  ...       ...
# 11705        1878   SSA_east  NaN     False
# 11706        1461   SSA_east  NaN     False
# 11707        1603   SSA_east  NaN     False
# 11708      277222   SSA_east  NaN     False
# 11709         671   SSA_east  NaN     False
#
# [1512 rows x 16 columns]
# countries with cy_id na below
#        Unnamed: 0                            measure_name  \
# 38          15073  DALYs (Disability-Adjusted Life Years)
# 39          15074  DALYs (Disability-Adjusted Life Years)
# 40          15081  DALYs (Disability-Adjusted Life Years)
# 41          15115  DALYs (Disability-Adjusted Life Years)
# 42          15116  DALYs (Disability-Adjusted Life Years)
# ...           ...                                     ...
# 11705      457074  DALYs (Disability-Adjusted Life Years)
# 11706      457075  DALYs (Disability-Adjusted Life Years)
# 11707      457078  DALYs (Disability-Adjusted Life Years)
# 11708      457862  DALYs (Disability-Adjusted Life Years)
# 11709      457886  DALYs (Disability-Adjusted Life Years)
#
#                            country   sex       age  rei_id  \
# 38                     South Sudan  btsx  All ages      83
# 39                     South Sudan  btsx  All ages      84
# 40                     South Sudan  btsx  All ages     238
# 41                     South Sudan  btsx  All ages      83
# 42                     South Sudan  btsx  All ages      84
# ...                            ...   ...       ...     ...
# 11705  United Republic of Tanzania  btsx  All ages      83
# 11706  United Republic of Tanzania  btsx  All ages      84
# 11707  United Republic of Tanzania  btsx  All ages     238
# 11708  United Republic of Tanzania  btsx  All ages     238
# 11709  United Republic of Tanzania  btsx  All ages     238
#
#                                               cause_name  cause_id  \
# 38                                            All causes       294
# 39                                            All causes       294
# 40                                            All causes       294
# 41                                            All causes       294
# 42                                            All causes       294
# ...                                                  ...       ...
# 11705  Communicable, maternal, neonatal, and nutritio...       295
# 11706  Communicable, maternal, neonatal, and nutritio...       295
# 11707  Communicable, maternal, neonatal, and nutritio...       295
# 11708                       Lower respiratory infections       322
# 11709                       Lower respiratory infections       322
#
#                                 rei_name  year_id  daly_mean  daly_upper  \
# 38                   Unsafe water source     1990     387194      679639
# 39                     Unsafe sanitation     1990     292342      518583
# 40     No access to handwashing facility     1990     339585      503025
# 41                   Unsafe water source     1990       6608       11598
# 42                     Unsafe sanitation     1990       4989        8850
# ...                                  ...      ...        ...         ...
# 11705                Unsafe water source     2007       2593        3429
# 11706                  Unsafe sanitation     2007       1920        2506
# 11707  No access to handwashing facility     2007       2455        3334
# 11708  No access to handwashing facility     2007     600721      919424
# 11709  No access to handwashing facility     2007       1454        2225
#
#        daly_lower region_SSA  iso  valid_id
# 38         234344   SSA_east  SSD     False
# 39         182239   SSA_east  SSD     False
# 40         211039   SSA_east  SSD     False
# 41           3999   SSA_east  SSD     False
# 42           3110   SSA_east  SSD     False
# ...           ...        ...  ...       ...
# 11705        1878   SSA_east  NaN     False
# 11706        1461   SSA_east  NaN     False
# 11707        1603   SSA_east  NaN     False
# 11708      277222   SSA_east  NaN     False
# 11709         671   SSA_east  NaN     False
#
# [1512 rows x 16 columns]

# %%
data_DALY = data_DALY.pivot_table(index=['c_id','year_id'],columns=['cause_name','rei_name','sex','age'],values=['daly_mean'],  aggfunc= 'sum')

data_DALY.assign(**data_DALY.index.to_frame()) #need to do this if the data is multihierarchical

data_DALY.columns = ['_'.join(col) for col in data_DALY.columns]
data_DALY=data_DALY.reset_index()
data_DALY
# Out:
#      c_id  year_id  \
# 0      55     1990
# 1      55     1991
# 2      55     1992
# 3      55     1993
# 4      55     1994
# ..    ...      ...
# 361   246     2015
# 362   246     2016
# 363   246     2017
# 364   246     2018
# 365   246     2019
#
#      daly_mean_All causes_No access to handwashing facility_btsx_All ages  \
# 0                                                29741
# 1                                                29506
# 2                                                29414
# 3                                                33000
# 4                                                30096
# ..                                                 ...
# 361                                             343504
# 362                                             318589
# 363                                             295386
# 364                                             284794
# 365                                             276211
#
#      daly_mean_All causes_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_All causes_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                29741
# 1                                                29506
# 2                                                29414
# 3                                                33000
# 4                                                30096
# ..                                                 ...
# 361                                             343504
# 362                                             318589
# 363                                             295386
# 364                                             284794
# 365                                             276211
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                19978
# 1                                                19229
# 2                                                18884
# 3                                                22091
# 4                                                18871
# ..                                                 ...
# 361                                             180051
# 362                                             168315
# 363                                             159230
# 364                                             155251
# 365                                             150689
#
#      daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Diarrheal diseases_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Enteric infections_No access to handwashing facility_btsx_All ages  \
# 0                                                19978
# 1                                                19229
# 2                                                18884
# 3                                                22091
# 4                                                18871
# ..                                                 ...
# 361                                             180051
# 362                                             168315
# 363                                             159230
# 364                                             155251
# 365                                             150689
#
#      daly_mean_Enteric infections_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Enteric infections_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Lower respiratory infections_No access to handwashing facility_btsx_All ages  \
# 0                                                 9763
# 1                                                10276
# 2                                                10529
# 3                                                10908
# 4                                                11223
# ..                                                 ...
# 361                                             163451
# 362                                             150272
# 363                                             136154
# 364                                             129541
# 365                                             125521
#
#      daly_mean_Respiratory infections and tuberculosis_No access to handwashing facility_btsx_All ages
# 0                                                 9763
# 1                                                10276
# 2                                                10529
# 3                                                10908
# 4                                                11223
# ..                                                 ...
# 361                                             163451
# 362                                             150272
# 363                                             136154
# 364                                             129541
# 365                                             125521
#
# [366 rows x 16 columns]

# %% [markdown]
# ## Merge

# %%
data_DALY
# Out:
#      c_id  year_id  \
# 0      55     1990
# 1      55     1991
# 2      55     1992
# 3      55     1993
# 4      55     1994
# ..    ...      ...
# 361   246     2015
# 362   246     2016
# 363   246     2017
# 364   246     2018
# 365   246     2019
#
#      daly_mean_All causes_No access to handwashing facility_btsx_All ages  \
# 0                                                29741
# 1                                                29506
# 2                                                29414
# 3                                                33000
# 4                                                30096
# ..                                                 ...
# 361                                             343504
# 362                                             318589
# 363                                             295386
# 364                                             284794
# 365                                             276211
#
#      daly_mean_All causes_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_All causes_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                29741
# 1                                                29506
# 2                                                29414
# 3                                                33000
# 4                                                30096
# ..                                                 ...
# 361                                             343504
# 362                                             318589
# 363                                             295386
# 364                                             284794
# 365                                             276211
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                19978
# 1                                                19229
# 2                                                18884
# 3                                                22091
# 4                                                18871
# ..                                                 ...
# 361                                             180051
# 362                                             168315
# 363                                             159230
# 364                                             155251
# 365                                             150689
#
#      daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Diarrheal diseases_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Enteric infections_No access to handwashing facility_btsx_All ages  \
# 0                                                19978
# 1                                                19229
# 2                                                18884
# 3                                                22091
# 4                                                18871
# ..                                                 ...
# 361                                             180051
# 362                                             168315
# 363                                             159230
# 364                                             155251
# 365                                             150689
#
#      daly_mean_Enteric infections_Unsafe sanitation_btsx_All ages  \
# 0                                                39381
# 1                                                37894
# 2                                                37234
# 3                                                43596
# 4                                                37263
# ..                                                 ...
# 361                                             360269
# 362                                             336675
# 363                                             318429
# 364                                             310288
# 365                                             301032
#
#      daly_mean_Enteric infections_Unsafe water source_btsx_All ages  \
# 0                                                52893
# 1                                                50901
# 2                                                49988
# 3                                                58480
# 4                                                49956
# ..                                                 ...
# 361                                             473833
# 362                                             442847
# 363                                             419033
# 364                                             408480
# 365                                             396386
#
#      daly_mean_Lower respiratory infections_No access to handwashing facility_btsx_All ages  \
# 0                                                 9763
# 1                                                10276
# 2                                                10529
# 3                                                10908
# 4                                                11223
# ..                                                 ...
# 361                                             163451
# 362                                             150272
# 363                                             136154
# 364                                             129541
# 365                                             125521
#
#      daly_mean_Respiratory infections and tuberculosis_No access to handwashing facility_btsx_All ages
# 0                                                 9763
# 1                                                10276
# 2                                                10529
# 3                                                10908
# 4                                                11223
# ..                                                 ...
# 361                                             163451
# 362                                             150272
# 363                                             136154
# 364                                             129541
# 365                                             125521
#
# [366 rows x 16 columns]

# %%
list(data_DALY.c_id.unique())
# Out:
# [55, 56, 57, 120, 155, 157, 158, 159, 162, 172, 191, 235, 237, 246]

# %%
#import the control variables
#data_dah = pd.read_csv('control variables/data_dah.csv')
#data_wdi = pd.read_csv('cntrol variables/data_wdi.csv')
#data_vn = pd.read_csv('control variables/data_vn.csv')
#data_wash = pd.read_csv('control variables/data_wash.csv')
#data_exp =  pd.read_csv('control variables/data_exp.csv')

# %%
#merge the datasets on c_id and year
data_merged = pd.merge(data_DALY, data_conflict, how="outer", on=["c_id", "year_id"])

# %%
data_merged.columns
# Out:
# Index(['c_id', 'year_id',
#        'daly_mean_All causes_No access to handwashing facility_btsx_All ages',
#        'daly_mean_All causes_Unsafe sanitation_btsx_All ages',
#        'daly_mean_All causes_Unsafe water source_btsx_All ages',
#        'daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages',
#        'daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages',
#        'daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages',
#        'daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages',
#        'daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages',
#        'daly_mean_Diarrheal diseases_Unsafe water source_btsx_All ages',
#        'daly_mean_Enteric infections_No access to handwashing facility_btsx_All ages',
#        'daly_mean_Enteric infections_Unsafe sanitation_btsx_All ages',
#        'daly_mean_Enteric infections_Unsafe water source_btsx_All ages',
#        'daly_mean_Lower respiratory infections_No access to handwashing facility_btsx_All ages',
#        'daly_mean_Respiratory infections and tuberculosis_No access to handwashing facility_btsx_All ages',
#        'Unnamed: 0', 'best_ns', 'best_os', 'best_sb', 'best_all'],
#       dtype='object')

# %%
East_list = list(list(data_DALY['c_id'].drop_duplicates()))
print(East_list)
# Out:
# [55, 56, 57, 120, 155, 157, 158, 159, 162, 172, 191, 235, 237, 246]

# %%
data_merged = data_merged.loc[data_merged['c_id'].isin([235, 157, 155, 120, 172, 159, 55, 162, 158, 237, 191, 56, 57, 246])]
data_final = data_merged.groupby(['c_id','year_id']).sum().reset_index()
display(data_final)
# Out:
#      c_id  year_id  \
# 0      55     1989
# 1      55     1990
# 2      55     1991
# 3      55     1992
# 4      55     1993
# ..    ...      ...
# 389   246     2017
# 390   246     2018
# 391   246     2019
# 392   246     2020
# 393   246     2021
#
#      daly_mean_All causes_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                              29741.0
# 2                                              29506.0
# 3                                              29414.0
# 4                                              33000.0
# ..                                                 ...
# 389                                           295386.0
# 390                                           284794.0
# 391                                           276211.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_All causes_Unsafe sanitation_btsx_All ages  \
# 0                                                  0.0
# 1                                              39381.0
# 2                                              37894.0
# 3                                              37234.0
# 4                                              43596.0
# ..                                                 ...
# 389                                           318429.0
# 390                                           310288.0
# 391                                           301032.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_All causes_Unsafe water source_btsx_All ages  \
# 0                                                  0.0
# 1                                              52893.0
# 2                                              50901.0
# 3                                              49988.0
# 4                                              58480.0
# ..                                                 ...
# 389                                           419033.0
# 390                                           408480.0
# 391                                           396386.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                              29741.0
# 2                                              29506.0
# 3                                              29414.0
# 4                                              33000.0
# ..                                                 ...
# 389                                           295386.0
# 390                                           284794.0
# 391                                           276211.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages  \
# 0                                                  0.0
# 1                                              39381.0
# 2                                              37894.0
# 3                                              37234.0
# 4                                              43596.0
# ..                                                 ...
# 389                                           318429.0
# 390                                           310288.0
# 391                                           301032.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages  \
# 0                                                  0.0
# 1                                              52893.0
# 2                                              50901.0
# 3                                              49988.0
# 4                                              58480.0
# ..                                                 ...
# 389                                           419033.0
# 390                                           408480.0
# 391                                           396386.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                              19978.0
# 2                                              19229.0
# 3                                              18884.0
# 4                                              22091.0
# ..                                                 ...
# 389                                           159230.0
# 390                                           155251.0
# 391                                           150689.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages  ...  \
# 0                                                  0.0             ...
# 1                                              39381.0             ...
# 2                                              37894.0             ...
# 3                                              37234.0             ...
# 4                                              43596.0             ...
# ..                                                 ...             ...
# 389                                           318429.0             ...
# 390                                           310288.0             ...
# 391                                           301032.0             ...
# 392                                                0.0             ...
# 393                                                0.0             ...
#
#      daly_mean_Enteric infections_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                              19978.0
# 2                                              19229.0
# 3                                              18884.0
# 4                                              22091.0
# ..                                                 ...
# 389                                           159230.0
# 390                                           155251.0
# 391                                           150689.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Enteric infections_Unsafe sanitation_btsx_All ages  \
# 0                                                  0.0
# 1                                              39381.0
# 2                                              37894.0
# 3                                              37234.0
# 4                                              43596.0
# ..                                                 ...
# 389                                           318429.0
# 390                                           310288.0
# 391                                           301032.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Enteric infections_Unsafe water source_btsx_All ages  \
# 0                                                  0.0
# 1                                              52893.0
# 2                                              50901.0
# 3                                              49988.0
# 4                                              58480.0
# ..                                                 ...
# 389                                           419033.0
# 390                                           408480.0
# 391                                           396386.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Lower respiratory infections_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                               9763.0
# 2                                              10276.0
# 3                                              10529.0
# 4                                              10908.0
# ..                                                 ...
# 389                                           136154.0
# 390                                           129541.0
# 391                                           125521.0
# 392                                                0.0
# 393                                                0.0
#
#      daly_mean_Respiratory infections and tuberculosis_No access to handwashing facility_btsx_All ages  \
# 0                                                  0.0
# 1                                               9763.0
# 2                                              10276.0
# 3                                              10529.0
# 4                                              10908.0
# ..                                                 ...
# 389                                           136154.0
# 390                                           129541.0
# 391                                           125521.0
# 392                                                0.0
# 393                                                0.0
#
#      Unnamed: 0  best_ns  best_os  best_sb  best_all
# 0         414.0      0.0      0.0      6.0       6.0
# 1         415.0      0.0      0.0     60.0      60.0
# 2         416.0     15.0      0.0     59.0      74.0
# 3         417.0      0.0      0.0    129.0     129.0
# 4         418.0      0.0      0.0     33.0      33.0
# ..          ...      ...      ...      ...       ...
# 389      1823.0    533.0    254.0    484.0    1271.0
# 390      1824.0    480.0    194.0    543.0    1217.0
# 391      1825.0    409.0    118.0    115.0     642.0
# 392      1826.0    656.0     28.0     64.0     748.0
# 393      1827.0    651.0     46.0    188.0     885.0
#
# [394 rows x 21 columns]

# %%
data_final['daly_all'] = data_final['daly_mean_All causes_No access to handwashing facility_btsx_All ages'] + data_final['daly_mean_All causes_Unsafe sanitation_btsx_All ages'] + data_final['daly_mean_All causes_Unsafe water source_btsx_All ages']
data_final['daly_respirat'] = data_final['daly_mean_Respiratory infections and tuberculosis_No access to handwashing facility_btsx_All ages'] + data_final['daly_mean_Lower respiratory infections_No access to handwashing facility_btsx_All ages']
data_final['daly_enteric'] = data_final['daly_mean_Enteric infections_No access to handwashing facility_btsx_All ages']+data_final['daly_mean_Enteric infections_Unsafe sanitation_btsx_All ages']+data_final['daly_mean_Enteric infections_Unsafe water source_btsx_All ages']
data_final['daly_diarrheal'] = data_final['daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages']+data_final['daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages']+data_final['daly_mean_Diarrheal diseases_Unsafe water source_btsx_All ages']
data_final['daly_cmnn'] = data_final['daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages']+data_final['daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages']+data_final['daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages']

# %% [markdown]
# # descriptives

# %%
plot =figure, axes = plt.subplots(5,1,figsize=(10,60))
sns.histplot(data_final['daly_all'],kde = True,ax=axes[0])
sns.histplot(data_final['daly_respirat'],kde = True,ax=axes[1])
sns.histplot(data_final['daly_enteric'],kde = True,ax=axes[2])
sns.histplot(data_final['daly_diarrheal'],kde = True,ax=axes[3])
sns.histplot(data_final['daly_cmnn'],kde = True,ax=axes[4])

plt.savefig('daly1c.png')

# %%
figure, axes = plt.subplots(5,1,figsize=(10,60))
sns.lineplot(x= 'year_id',y='daly_all',data=data_final,ax=axes[0])
sns.lineplot(x= 'year_id',y='daly_respirat',data=data_final,ax=axes[1])
sns.lineplot(x= 'year_id',y='daly_enteric',data=data_final,ax=axes[2])
sns.lineplot(x= 'year_id',y='daly_diarrheal',data=data_final,ax=axes[3])
sns.lineplot(x= 'year_id',y='daly_cmnn',data=data_final,ax=axes[4])

plt.savefig('daly2.png')

# %%
figure, axes = plt.subplots(3,1,figsize=(10,60))
sns.histplot(data_final['best_ns'],kde = True,ax=axes[0])
sns.histplot(data_final['best_os'],kde = True,ax=axes[1])
sns.histplot(data_final['best_sb'],kde = True,ax=axes[2])
plt.savefig('conflict1.png')

# %%
figure, axes = plt.subplots(3,1,figsize=(10,60))
sns.lineplot(x= 'year_id',y='best_ns',data=data_final,ax=axes[0])
sns.lineplot(x= 'year_id',y='best_os',data=data_final,ax=axes[1])
sns.lineplot(x= 'year_id',y='best_sb',data=data_final,ax=axes[2])

plt.savefig('conflict2.png')

# %%
data_final.describe()
# Out:
#              c_id      year_id  \
# count  394.000000   394.000000
# mean   147.774112  2005.035533
# std     60.837390     9.324719
# min     55.000000  1989.000000
# 25%    120.000000  1997.000000
# 50%    158.000000  2005.000000
# 75%    172.000000  2013.000000
# max    246.000000  2021.000000
#
#        daly_mean_All causes_No access to handwashing facility_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        6.279431e+05
# std                                         8.518772e+05
# min                                         0.000000e+00
# 25%                                         1.620402e+05
# 50%                                         3.999860e+05
# 75%                                         7.749232e+05
# max                                         4.608832e+06
#
#        daly_mean_All causes_Unsafe sanitation_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        7.622587e+05
# std                                         1.036962e+06
# min                                         0.000000e+00
# 25%                                         1.323820e+05
# 50%                                         4.699890e+05
# 75%                                         1.014651e+06
# max                                         5.583132e+06
#
#        daly_mean_All causes_Unsafe water source_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        1.003150e+06
# std                                         1.337613e+06
# min                                         0.000000e+00
# 25%                                         1.972970e+05
# 50%                                         6.268490e+05
# 75%                                         1.313286e+06
# max                                         7.208305e+06
#
#        daly_mean_Communicable, maternal, neonatal, and nutritional diseases_No access to handwashing facility_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        6.279431e+05
# std                                         8.518772e+05
# min                                         0.000000e+00
# 25%                                         1.620402e+05
# 50%                                         3.999860e+05
# 75%                                         7.749232e+05
# max                                         4.608832e+06
#
#        daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe sanitation_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        7.622587e+05
# std                                         1.036962e+06
# min                                         0.000000e+00
# 25%                                         1.323820e+05
# 50%                                         4.699890e+05
# 75%                                         1.014651e+06
# max                                         5.583132e+06
#
#        daly_mean_Communicable, maternal, neonatal, and nutritional diseases_Unsafe water source_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        1.003150e+06
# std                                         1.337613e+06
# min                                         0.000000e+00
# 25%                                         1.972970e+05
# 50%                                         6.268490e+05
# 75%                                         1.313286e+06
# max                                         7.208305e+06
#
#        daly_mean_Diarrheal diseases_No access to handwashing facility_btsx_All ages  \
# count                                       3.940000e+02
# mean                                        3.830065e+05
# std                                         5.160999e+05
# min                                         0.000000e+00
# 25%                                         6.949475e+04
# 50%                                         2.387275e+05
# 75%                                         5.051625e+05
# max                                         2.774854e+06
#
#        daly_mean_Diarrheal diseases_Unsafe sanitation_btsx_All ages  ...  \
# count                                       3.940000e+02             ...
# mean                                        7.622587e+05             ...
# std                                         1.036962e+06             ...
# min                                         0.000000e+00             ...
# 25%                                         1.323820e+05             ...
# 50%                                         4.699890e+05             ...
# 75%                                         1.014651e+06             ...
# max                                         5.583132e+06             ...
#
#         Unnamed: 0      best_ns      best_os       best_sb      best_all  \
# count   394.000000   394.000000   394.000000    394.000000    394.000000
# mean    707.875635    84.715736    88.510152    687.482234    860.708122
# std     689.694255   245.071180   319.545130   4169.746853   4242.466358
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      0.000000      0.000000
# 50%     455.500000     0.000000     0.000000      0.000000     11.500000
# 75%    1319.750000    44.500000    31.750000     68.500000    369.500000
# max    1827.000000  3485.000000  3845.000000  49698.000000  49856.000000
#
#            daly_all  daly_respirat  daly_enteric  daly_diarrheal     daly_cmnn
# count  3.940000e+02   3.940000e+02  3.940000e+02    3.940000e+02  3.940000e+02
# mean   2.393352e+06   4.898715e+05  2.148415e+06    2.148415e+06  2.393352e+06
# std    3.224571e+06   6.789903e+05  2.890583e+06    2.890583e+06  3.224571e+06
# min    0.000000e+00   0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00
# 25%    4.983208e+05   1.386710e+05  3.995510e+05    3.995510e+05  4.983208e+05
# 50%    1.482337e+06   3.557640e+05  1.333224e+06    1.333224e+06  1.482337e+06
# 75%    3.101478e+06   5.922020e+05  2.822049e+06    2.822049e+06  3.101478e+06
# max    1.739555e+07   3.828782e+06  1.556629e+07    1.556629e+07  1.739555e+07
#
# [8 rows x 26 columns]

# %%
data_final.to_csv('data_final.csv')
